# %% [markdown]
# # PCA with data 'interpolation_10s_int'

# %%
import pandas as pd
import matplotlib.pyplot as plt

% matplotlib inline
import pca_script

# %%
root_dir = "data/interpolation_10s_int/"

# %%
name_HW1 = ['ZX_HW1_1', 'ZX_HW1_2', 'ZX_HW1_3', 'ZX_HW1_4', 'ZX_HW1_5', 'ZX_HW1_6']
name_HW2 = ['ZX_HW2_1', 'ZX_HW2_2', 'ZX_HW2_3', 'ZX_HW2_4', 'ZX_HW2_5', 'ZX_HW2_6']
name_HW_ = name_HW1 + name_HW2

# %% [markdown]
# ##  data_0134

# %%
data_0134 = pd.read_csv(root_dir+"0134.csv")

# %%
pca_script.pca_plot(data_0134[name_HW1])
# Out:
# [  9.99671071e-01   1.24311887e-04   1.03229741e-04   3.99165874e-05
#    3.48015876e-05   2.66695812e-05]
# [  8.15930909e+01   1.01463285e-02   8.42560507e-03   3.25798939e-03
#    2.84050342e-03   2.17676957e-03]

# %%
pca_script.pca_plot(data_0134[name_HW2])
# Out:
# [  9.99739422e-01   1.02851946e-04   8.85739161e-05   2.97649389e-05
#    2.66168237e-05   1.27700209e-05]
# [  9.38629950e+01   9.65650796e-03   8.31598000e-03   2.79455451e-03
#    2.49898598e-03   1.19894483e-03]

# %%
pca_script.pca_plot(data_0134[name_HW_])
# Out:
# [  9.79734725e-01   1.99729494e-02   5.88041953e-05   5.42078008e-05
#    4.79865231e-05   4.72179784e-05   1.85619603e-05   1.62216829e-05
#    1.58699271e-05   1.42362693e-05   1.23884070e-05   6.83055666e-06]
# [  1.71950692e+02   3.50540038e+00   1.03205713e-02   9.51387008e-03
#    8.42198981e-03   8.28710452e-03   3.25776135e-03   2.84702536e-03
#    2.78528961e-03   2.49857058e-03   2.17425707e-03   1.19881323e-03]

# %% [markdown]
# ##  data_0141

# %%
data_0141 = pd.read_csv(root_dir+"0141.csv")

# %%
pca_script.pca_plot(data_0141[name_HW1])
# Out:
# [  9.99567882e-01   1.67582030e-04   1.52632173e-04   5.16516191e-05
#    3.37022403e-05   2.65498388e-05]
# [  4.04142171e+01   6.77562441e-03   6.17117645e-03   2.08836216e-03
#    1.36263848e-03   1.07345481e-03]

# %%
pca_script.pca_plot(data_0141[name_HW2])
# Out:
# [  9.99594289e-01   1.69650540e-04   1.20791114e-04   5.15439295e-05
#    4.05436995e-05   2.31816292e-05]
# [  6.08490983e+01   1.03272723e-02   7.35301360e-03   3.13767462e-03
#    2.46804887e-03   1.41115376e-03]

# %%
pca_script.pca_plot(data_0141[name_HW_])
# Out:
# [  9.15190313e-01   8.43938369e-02   1.01751569e-04   7.25698378e-05
#    6.67581059e-05   6.08730491e-05   3.09721721e-05   2.43533946e-05
#    2.05986825e-05   1.39288113e-05   1.34501184e-05   1.05944731e-05]
# [  9.27137974e+01   8.54955847e+00   1.03079919e-02   7.35172253e-03
#    6.76296222e-03   6.16677370e-03   3.13765088e-03   2.46713242e-03
#    2.08675950e-03   1.41106497e-03   1.36257075e-03   1.07327822e-03]

# %% [markdown]
# ##  data_0192

# %%
data_0192 = pd.read_csv(root_dir+"0192.csv")

# %%
pca_script.pca_plot(data_0192[name_HW1])
# Out:
# [  9.99536097e-01   1.87075086e-04   1.61073292e-04   4.80458868e-05
#    4.46657553e-05   2.30430967e-05]
# [  6.25157039e+01   1.17005586e-02   1.00742837e-02   3.00501647e-03
#    2.79360709e-03   1.44122400e-03]

# %%
pca_script.pca_plot(data_0192[name_HW2])
# Out:
# [  9.99632812e-01   1.37454663e-04   1.06694940e-04   4.87387678e-05
#    4.24595953e-05   3.18397422e-05]
# [  5.51775170e+01   7.58719295e-03   5.88932433e-03   2.69027202e-03
#    2.34367561e-03   1.75748324e-03]

# %%
pca_script.pca_plot(data_0192[name_HW_])
# Out:
# [  8.61585361e-01   1.37996165e-01   9.93676146e-05   8.56356463e-05
#    6.43984254e-05   4.99528791e-05   2.55218266e-05   2.37347429e-05
#    2.28114433e-05   1.99002969e-05   1.49131105e-05   1.22373183e-05]
# [  1.01445217e+02   1.62480140e+01   1.16997917e-02   1.00829554e-02
#    7.58243182e-03   5.88157705e-03   3.00500376e-03   2.79458805e-03
#    2.68587644e-03   2.34311078e-03   1.75590696e-03   1.44085250e-03]

# %% [markdown]
# ## data_0394

# %%
data_0394 = pd.read_csv(root_dir+"0394.csv")

# %%
pca_script.pca_plot(data_0394[name_HW1])
# Out:
# [  9.99496254e-01   2.39265933e-04   1.32330767e-04   5.15997126e-05
#    4.64348296e-05   3.41149093e-05]
# [  4.75100740e+01   1.13732714e-02   6.29021319e-03   2.45274172e-03
#    2.20723408e-03   1.62161875e-03]

# %%
pca_script.pca_plot(data_0394[name_HW2])
# Out:
# [  9.99801280e-01   8.64508283e-05   6.03637855e-05   2.48666544e-05
#    1.41147954e-05   1.29243853e-05]
# [  1.26066101e+02   1.09006850e-02   7.61133961e-03   3.13546525e-03
#    1.77975090e-03   1.62965071e-03]

# %%
pca_script.pca_plot(data_0394[name_HW_])
# Out:
# [  9.77466513e-01   2.22513752e-02   6.55399526e-05   6.27428994e-05
#    4.37789533e-05   3.62203369e-05   1.80437556e-05   1.41217716e-05
#    1.27035663e-05   1.02491928e-05   9.42902798e-06   9.28207144e-06]
# [  1.69712796e+02   3.86339896e+00   1.13793859e-02   1.08937470e-02
#    7.60112851e-03   6.28876241e-03   3.13285026e-03   2.45189509e-03
#    2.20565895e-03   1.77951791e-03   1.63711665e-03   1.61160130e-03]

# %% [markdown]
# ## data_0500

# %%
data_0500 = pd.read_csv(root_dir+"0500.csv")

# %%
pca_script.pca_plot(data_0500[name_HW1])
# Out:
# [  9.99452122e-01   2.79063499e-04   1.52615071e-04   5.54983564e-05
#    3.59243422e-05   2.47769903e-05]
# [  5.77958929e+01   1.61375655e-02   8.82535951e-03   3.20933539e-03
#    2.07741761e-03   1.43279327e-03]

# %%
pca_script.pca_plot(data_0500[name_HW2])
# Out:
# [  9.99369965e-01   2.49148849e-04   1.80684858e-04   8.96888080e-05
#    6.44124051e-05   4.61004124e-05]
# [  3.79929862e+01   9.47187640e-03   6.86908508e-03   3.40969387e-03
#    2.44876243e-03   1.75259653e-03]

# %%
pca_script.pca_plot(data_0500[name_HW_])
# Out:
# [  9.55314275e-01   4.41081860e-02   1.65603491e-04   9.92508785e-05
#    9.17034716e-05   7.16245902e-05   3.56179849e-05   3.34166617e-05
#    2.55444952e-05   2.17210085e-05   1.81712217e-05   1.48849146e-05]
# [  9.15616320e+01   4.22752764e+00   1.58721860e-02   9.51265217e-03
#    8.78927463e-03   6.86482401e-03   3.41378844e-03   3.20280368e-03
#    2.44829972e-03   2.08183950e-03   1.74161191e-03   1.42663740e-03]

# %% [markdown]
# ## data_0520

# %%
data_0520 = pd.read_csv(root_dir+"0520.csv")

# %%
pca_script.pca_plot(data_0520[name_HW1])
# Out:
# [  9.99860112e-01   5.35525074e-05   4.31174638e-05   1.77219554e-05
#    1.58565320e-05   9.63960020e-06]
# [  1.80426742e+02   9.66365624e-03   7.78063192e-03   3.19796202e-03
#    2.86134266e-03   1.73948499e-03]

# %%
pca_script.pca_plot(data_0520[name_HW2])
# Out:
# [  9.99821433e-01   6.24647134e-05   5.64013496e-05   2.43852178e-05
#    2.03977891e-05   1.49179093e-05]
# [  1.43172568e+02   8.94483065e-03   8.07656824e-03   3.49191779e-03
#    2.92092542e-03   2.13621683e-03]

# %%
pca_script.pca_plot(data_0520[name_HW_])
# Out:
# [  9.75798309e-01   2.40447260e-02   2.98578856e-05   2.76286740e-05
#    2.49536947e-05   2.40332136e-05   1.07804238e-05   9.87412363e-06
#    9.02447458e-06   8.84050664e-06   6.59736098e-06   5.37455263e-06]
# [  3.15817242e+02   7.78207852e+00   9.66350832e-03   8.94202373e-03
#    8.07626634e-03   7.77835252e-03   3.48908549e-03   3.19576133e-03
#    2.92077231e-03   2.86123106e-03   2.13523669e-03   1.73947462e-03]

# %% [markdown]
# ## data_0609

# %%
data_0609 = pd.read_csv(root_dir + "0609.csv")

# %%
pca_script.pca_plot(data_0609[name_HW1])
# Out:
# [  9.99855688e-01   5.31577655e-05   4.80119895e-05   1.87278668e-05
#    1.34221265e-05   1.09924610e-05]
# [  1.20456387e+02   6.40411658e-03   5.78418553e-03   2.25621677e-03
#    1.61701422e-03   1.32430325e-03]

# %%
pca_script.pca_plot(data_0609[name_HW2])
# Out:
# [  9.99872788e-01   5.10866760e-05   3.89240076e-05   2.00559437e-05
#    1.16840076e-05   5.46088146e-06]
# [  1.55898978e+02   7.96537388e-03   6.06898506e-03   3.12709893e-03
#    1.82175659e-03   8.51454155e-04]

# %%
pca_script.pca_plot(data_0609[name_HW_])
# Out:
# [  9.86957106e-01   1.29082367e-02   2.88365618e-05   2.31681380e-05
#    2.20369673e-05   2.08410092e-05   1.13141110e-05   8.17071667e-06
#    6.60167951e-06   5.81822808e-06   4.79106781e-06   3.07901229e-06]
# [  2.72787627e+02   3.56774093e+00   7.97021189e-03   6.40350159e-03
#    6.09085439e-03   5.76030043e-03   3.12713641e-03   2.25832551e-03
#    1.82465527e-03   1.60811511e-03   1.32421562e-03   8.51016169e-04]

# %% [markdown]
# ## data_0790

# %%
data_0790 = pd.read_csv(root_dir+"0790.csv")

# %%
pca_script.pca_plot(data_0790[name_HW1])
# Out:
# [  9.99740452e-01   1.08078931e-04   7.41401147e-05   3.23743212e-05
#    2.50436763e-05   1.99107016e-05]
# [  1.01756594e+02   1.10005991e-02   7.54620418e-03   3.29515593e-03
#    2.54902080e-03   2.02657118e-03]

# %%
pca_script.pca_plot(data_0790[name_HW2])
# Out:
# [  9.99778892e-01   8.87728145e-05   6.20889650e-05   2.93236932e-05
#    2.59550377e-05   1.49678463e-05]
# [  1.68142366e+02   1.49297722e-02   1.04420943e-02   4.93164560e-03
#    4.36510661e-03   2.51728569e-03]

# %%
pca_script.pca_plot(data_0790[name_HW_])
# Out:
# [  9.69377452e-01   3.03870428e-02   5.52601320e-05   4.07968109e-05
#    3.86174141e-05   2.79371009e-05   1.82847117e-05   1.61742441e-05
#    1.21798834e-05   9.43848479e-06   9.33078117e-06   7.48596670e-06]
# [  2.61695623e+02   8.20336401e+00   1.49181669e-02   1.10136117e-02
#    1.04252561e-02   7.54197139e-03   4.93618764e-03   4.36644040e-03
#    3.28811257e-03   2.54803756e-03   2.51896161e-03   2.02093077e-03]
