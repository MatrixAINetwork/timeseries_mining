# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

from plot_script import *

# %%
data_0134 = pd.read_csv("data/interpolation_10s_int/0134.csv")
print(data_0134.head())
print(data_0134.info())
print(data_0134.describe())
print(data_0134.columns)
# Out:
#                   BTSJ  ZX_WD_1_1  ZX_WD_1_2  ZX_WD_1_3  ZX_WD_1_4  ZX_WD_1_5  \
# 0  2016-05-20 00:01:07         27         26         28         28         26
# 1  2016-05-20 00:01:17         27         26         28         28         26
# 2  2016-05-20 00:01:27         27         26         28         28         26
# 3  2016-05-20 00:01:37         27         26         28         28         26
# 4  2016-05-20 00:01:47         27         26         28         28         26
#
#    ZX_WD_1_6  ZX_WD_1_7  ZX_WD_1_8  ZX_WD_2_1    ...     ZX_HW1_2  ZX_HW2_2  \
# 0         26        130        130         27    ...           26        26
# 1         26        130        130         27    ...           26        26
# 2         26        130        130         27    ...           26        26
# 3         26        130        130         27    ...           26        26
# 4         26        130        130         27    ...           26        26
#
# ...

# %%
plot_ZH_HW(data_0134)
