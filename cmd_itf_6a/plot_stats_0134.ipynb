# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from preprocess import base
from visual_data import plot_statistics

% matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from preprocess import base
from visual_data import plot_statistics

% matplotlib inline

# %% [markdown]
# import importlib
# importlib.reload(plot_statistics)

# %%
root_dir = os.getcwd()
root_dir = root_dir + "/data_0134/smooth_mean_interpolate_bin_mean/"

# %%
filelist = base.get_files_csv(root_dir)
len(filelist)
print(filelist)
# Out:
# ['00_233_134_2016-05-20.csv' '01_233_134_2016-06-25.csv'
#  '02_233_134_2016-07-11.csv' '03_233_134_2016-07-04.csv'
#  '04_233_134_2016-07-02.csv' '05_233_134_2016-06-16.csv'
#  '06_233_134_2016-07-13.csv' '07_233_134_2016-07-07.csv'
#  '08_233_134_2016-06-19.csv' '09_233_134_2016-06-30.csv'
#  '10_233_134_2016-06-29.csv']

# %%
data = pd.read_csv(root_dir+filelist[0])
plot_statistics.plot_ZX_HW(data)

# %%
data = pd.read_csv(root_dir+filelist[1])
plot_statistics.plot_ZX_HW(data)

# %%
data = pd.read_csv(root_dir+filelist[2])
plot_statistics.plot_ZX_HW(data)

# %%
data = pd.read_csv(root_dir+filelist[3])
plot_statistics.plot_ZX_HW(data)

# %%
data = pd.read_csv(root_dir+filelist[4])
plot_statistics.plot_ZX_HW(data)

# %%
data = pd.read_csv(root_dir+filelist[5])
plot_statistics.plot_ZX_HW(data)

# %%
data = pd.read_csv(root_dir+filelist[6])
plot_statistics.plot_ZX_HW(data)

# %%
data = pd.read_csv(root_dir+filelist[7])
plot_statistics.plot_ZX_HW(data)

# %%
data = pd.read_csv(root_dir+filelist[8])
plot_statistics.plot_ZX_HW(data)

# %%
data = pd.read_csv(root_dir+filelist[9])
plot_statistics.plot_ZX_HW(data)

# %%
data = pd.read_csv(root_dir+filelist[10])
plot_statistics.plot_ZX_HW(data)

# %%
plot_statistics.plot_stats_ZX_HW_batch(root_dir, np.mean)

# %%
plot_statistics.plot_stats_ZX_HW_batch(root_dir, np.std)

# %%
print(filelist[0])
data = pd.read_csv(root_dir+filelist[0])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 00_233_134_2016-05-20.csv

# %%
print(filelist[1])
data = pd.read_csv(root_dir+filelist[1])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 01_233_134_2016-06-25.csv

# %%
print(filelist[2])
data = pd.read_csv(root_dir+filelist[2])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 02_233_134_2016-07-11.csv

# %%
print(filelist[3])
data = pd.read_csv(root_dir+filelist[3])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 03_233_134_2016-07-04.csv

# %%
print(filelist[4])
data = pd.read_csv(root_dir+filelist[4])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 04_233_134_2016-07-02.csv

# %%
print(filelist[5])
data = pd.read_csv(root_dir+filelist[5])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 05_233_134_2016-06-16.csv

# %%
print(filelist[6])
data = pd.read_csv(root_dir+filelist[6])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 06_233_134_2016-07-13.csv

# %%
print(filelist[7])
data = pd.read_csv(root_dir+filelist[7])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 07_233_134_2016-07-07.csv

# %%
print(filelist[8])
data = pd.read_csv(root_dir+filelist[8])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 08_233_134_2016-06-19.csv

# %%
print(filelist[9])
data = pd.read_csv(root_dir+filelist[9])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 09_233_134_2016-06-30.csv

# %%
print(filelist[10])
data = pd.read_csv(root_dir+filelist[10])
plot_statistics.plot_stats_ZX_WD_No1(data)
# Out:
# 10_233_134_2016-06-29.csv
